# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('out/initialFT.dat')
print(data.shape)

plt.plot(data[:,0], data[:,3])
# Out:
# (1000, 4)

# %%
data = np.loadtxt('out/finalFT.dat')
print(data.shape)

plt.plot(data[:,0], data[:,3])
# Out:
# (1000, 4)
